# %% [markdown]
# <a href="https://colab.research.google.com/github/shainy05/PyContacts/blob/main/py_contacts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
//Py-contacts using python
def main():
    contacts=[]
    while True:
        print("1.Add")
        print("2.View")
        print("3.Search")
        print("4.Delete")
        print("5.Quit")
        try:
            num=int(input("Enter any number between 1 to 5:"))
            print(f"The number is:{num}")
        except:
            print("Please enter a valid number")
            continue
        if num>5 or num<1:
            print("Invalid number")
        elif num==1:
            add_contact(contacts)
        elif num==2:
            view_contact(contacts)
        elif num==3:
            search_contact(contacts)
        elif num==4:
            delete_contact(contacts)
        elif num==5:
            break

def add_contact(contacts):
    name=input("Enter the name:")
    phone=int(input("Enter the phone number:"))
    email=input("Enter the email:")
    contact={"name":name,"phone":phone,"email":email}
    contacts.append(contact)
def view_contact(contacts):
    if not contacts:
        print("No cantacts stored!")
    else:
        for contact in contacts:
            print(contact["name"])
            print(contact["phone"])
            print(contact["email"])
def search_contact(contacts):
    name1=input("Enter any name:")
    found=False
    for contact in contacts:
        if name1==contact["name"]:
            print(contact["name"])
            print(contact["phone"])
            print(contact["email"])
            found=True
    if not found:
        print("Invalid name!")
def delete_contact(contacts):
 name2=input("Enter any name:")
 found=False
 for contact in contacts:
  if name2==contact["name"]:
   contact_to_delete=contact
   found=True
 if found:
        contacts.remove(contact_to_delete)
        print("Contact deleted.")
 else:
  print("Invalid name!")

main()



Contact book
